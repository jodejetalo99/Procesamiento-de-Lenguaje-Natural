# %% [markdown]
# ### José de Jesús Tapia López
# ### Procesamiento de Lenguaje Natural
# ### 25 de Noviembre del 2020
# ### Tema 6 - Actividad Sumativa 2

# %% [markdown]
# Elegir uno de los sistemas que se han presentado en la presentación Herramientas.
#
# Analizar el texto El ramo azul, de Octavio Paz y responder las siguientes preguntas:
#
# 1. Tokeniza el texto. ¿Cuántas palabras hay? (sin símbolos de puntuación).
# 2. Para cada palabra, da el lema y la raíz.
# 3. ¿Cuántas palabras diferentes hay?
# 4. Después de lematizar las palabras, ¿cuántas palabras diferentes hay?
# 5. ¿Cuál es la diversidad léxica del texto dado? (relación de palabras únicas con respecto al número total de palabras)
# 6. ¿Cuáles son las 20 palabras léxicas más frecuentes en el texto? ¿Cuál es su frecuencia?
# 7. ¿Cuál es el número promedio de palabras por oración?
# 8. ¿Cuál  es la frecuencia de de sustantivos, adjetivos y verbos en el texto?.
#
# Entregar Notebook con código bien comentado.

# %%
import nltk
#nltk.download('punkt')
from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords
#nltk.download('wordnet')
#nltk.download('brown')
#nltk.download('universal_tagset')
import spacy
from collections import Counter

# %%
pip install stanza
# Out:
# Collecting stanza
#   Using cached https://files.pythonhosted.org/packages/e7/8b/3a9e7a8d8cb14ad6afffc3983b7a7322a3a24d94ebc978a70746fcffc085/stanza-1.1.1-py3-none-any.whl
# Requirement already satisfied: requests in /home/jodejetalo99/anaconda3/lib/python3.7/site-packages (from stanza) (2.24.0)
# Requirement already satisfied: numpy in /home/jodejetalo99/anaconda3/lib/python3.7/site-packages (from stanza) (1.19.4)
# Requirement already satisfied: tqdm in /home/jodejetalo99/anaconda3/lib/python3.7/site-packages (from stanza) (4.50.0)
# Collecting torch>=1.3.0 (from stanza)
#   Downloading https://files.pythonhosted.org/packages/d9/74/d52c014fbfb50aefc084d2bf5ffaa0a8456f69c586782b59f93ef45e2da9/torch-1.7.0-cp37-cp37m-manylinux1_x86_64.whl (776.7MB)
#     52% |█████████████████               | 411.1MB 2.8MB/s eta 0:02:1060% |                                | 337kB 2.6MB/s eta 0:04:59    0% |                                | 573kB 5.6MB/s eta 0:02:19    0% |▏                               | 2.8MB 2.3MB/s eta 0:05:33    1% |▋                               | 13.8MB 2.7MB/s eta 0:04:43    3% |█                               | 23.7MB 424kB/s eta 0:29:36    3% |█▏                              | 28.0MB 1.8MB/s eta 0:06:56    3% |█▎                              | 29.8MB 1.6MB/s eta 0:07:57    4% |█▎                              | 31.1MB 1.2MB/s eta 0:10:35    4% |█▍                              | 34.7MB 2.0MB/s eta 0:06:11    5% |█▉                              | 43.8MB 2.8MB/s eta 0:04:24    5% |█▉                              | 44.0MB 1.9MB/s eta 0:06:33    5% |█▉                              | 44.4MB 2.1MB/s eta 0:05:44    6% |██▏                             | 52.9MB 2.5MB/s eta 0:04:54    6% |██▏                             | 53.1MB 10.2MB/s eta 0:01:12    6% |██▎                             | 54.1MB 711kB/s eta 0:16:57    7% |██▍                             | 58.5MB 1.3MB/s eta 0:09:03    8% |██▋                             | 62.9MB 2.3MB/s eta 0:05:07    8% |██▉                             | 67.5MB 966kB/s eta 0:12:14    8% |██▉                             | 67.6MB 1.3MB/s eta 0:08:46    8% |██▉                             | 67.9MB 1.4MB/s eta 0:08:38    8% |██▉                             | 69.5MB 1.6MB/s eta 0:07:16    9% |███                             | 70.3MB 889kB/s eta 0:13:15    9% |███                             | 74.3MB 1.4MB/s eta 0:08:08    9% |███                             | 74.4MB 1.4MB/s eta 0:08:33    10% |███▎                            | 79.4MB 2.5MB/s eta 0:04:40    10% |███▍                            | 81.3MB 633kB/s eta 0:18:18    11% |███▋                            | 88.3MB 2.6MB/s eta 0:04:24    11% |███▊                            | 90.1MB 2.8MB/s eta 0:04:04    12% |████                            | 97.0MB 2.3MB/s eta 0:04:56    12% |████                            | 97.2MB 2.4MB/s eta 0:04:44    12% |████                            | 97.9MB 7.2MB/s eta 0:01:35    12% |████                            | 99.7MB 1.8MB/s eta 0:06:25    13% |████▏                           | 102.1MB 2.5MB/s eta 0:04:31    15% |████▉                           | 117.3MB 2.7MB/s eta 0:04:01    15% |█████                           | 121.6MB 2.8MB/s eta 0:03:51    15% |█████                           | 122.8MB 2.5MB/s eta 0:04:18    17% |█████▋                          | 135.8MB 1.6MB/s eta 0:06:31    17% |█████▋                          | 136.6MB 2.4MB/s eta 0:04:25    18% |██████                          | 144.0MB 1.4MB/s eta 0:07:40    18% |██████                          | 144.3MB 2.6MB/s eta 0:03:59    20% |██████▋                         | 159.2MB 2.5MB/s eta 0:04:10    20% |██████▋                         | 161.2MB 2.7MB/s eta 0:03:50    20% |██████▊                         | 162.7MB 2.9MB/s eta 0:03:34    21% |██████▊                         | 163.3MB 2.4MB/s eta 0:04:11    21% |██████▊                         | 164.4MB 1.3MB/s eta 0:07:57    21% |██████▉                         | 164.6MB 532kB/s eta 0:19:09    21% |██████▉                         | 165.4MB 2.2MB/s eta 0:04:41    21% |███████                         | 168.8MB 2.6MB/s eta 0:03:59    23% |███████▌                        | 181.5MB 2.5MB/s eta 0:03:54    23% |███████▌                        | 182.1MB 2.9MB/s eta 0:03:27    24% |███████▊                        | 187.3MB 2.3MB/s eta 0:04:14    24% |███████▉                        | 189.6MB 2.6MB/s eta 0:03:43    25% |████████                        | 195.6MB 2.6MB/s eta 0:03:40    26% |████████▍                       | 203.3MB 2.9MB/s eta 0:03:22    26% |████████▋                       | 208.3MB 2.8MB/s eta 0:03:20    26% |████████▋                       | 209.1MB 2.2MB/s eta 0:04:17    27% |█████████                       | 215.9MB 2.8MB/s eta 0:03:23  ...

# %%
# abrimos el archivo txt que nos fue brindado, lo leemos y lo guardamos en la variable el_ramo_azul
with open('elramoazul.txt', 'r') as archivo:
    # leemos el archivo y reemplazamos todos los saltos de línea con espacios en blanco
    el_ramo_azul = archivo.read().replace('\n', ' ')

# %%
# eliminamos signos de puntuación

signos_puntuacion = ('¡','!','.',':',',',';','*','?','¿','*','-','–','(',')','[',']','\'','"','“','”','>','<')
el_ramo_azul_prep = "".join(c for c in el_ramo_azul if c not in signos_puntuacion)

# pasamos todo a minúsculas
el_ramo_azul_prep = el_ramo_azul_prep.lower()

# %% [markdown]
# 1. Tokeniza el texto. ¿Cuántas palabras hay? (sin símbolos de puntuación)

# %%
# usamos la biblioteca de nltk con el respectivo método que tokeniza
tokens = nltk.word_tokenize(el_ramo_azul_prep)
print("Hay {} palabras".format(len(tokens)))
# Out:
# Hay 826 palabras

# %% [markdown]
# 2. Para cada palabra, da el lema y la raíz.

# %%
# Inicializamos el lematizador de Wordnet (nltk)
WNlemma = nltk.WordNetLemmatizer()
# Obtenemos el lema de cada token (cada palabra) en lista por comprensión
lemas = [(t,WNlemma.lemmatize(t)) for t in tokens]
lemas
# Out:
# [('el', 'el'),
#  ('ramo', 'ramo'),
#  ('azul', 'azul'),
#  ('un', 'un'),
#  ('cuento', 'cuento'),
#  ('de', 'de'),
#  ('octavio', 'octavio'),
#  ('paz', 'paz'),
#  ('desperté', 'desperté'),
#  ('cubierto', 'cubierto'),
#  ('de', 'de'),
#  ('sudor', 'sudor'),
#  ('del', 'del'),
#  ('piso', 'piso'),
#  ('de', 'de'),
#  ('ladrillos', 'ladrillos'),
#  ('rojos', 'rojos'),
#  ('recién', 'recién'),
#  ('regados', 'regados'),
#  ('subía', 'subía'),
#  ('un', 'un'),
#  ('vapor', 'vapor'),
#  ('caliente', 'caliente'),
#  ('una', 'una'),
#  ('mariposa', 'mariposa'),
#  ('de', 'de'),
#  ('alas', 'ala'),
#  ('grisáceas', 'grisáceas'),
#  ('revoloteaba', 'revoloteaba'),
#  ('encandilada', 'encandilada'),
#  ('alrededor', 'alrededor'),
#  ('del', 'del'),
#  ('foco', 'foco'),
#  ('amarillento', 'amarillento'),
#  ('salté', 'salté'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('hamaca', 'hamaca'),
#  ('y', 'y'),
#  ('descalzo', 'descalzo'),
#  ('atravesé', 'atravesé'),
#  ('el', 'el'),
#  ('cuarto', 'cuarto'),
#  ('cuidando', 'cuidando'),
#  ('no', 'no'),
#  ('pisar', 'pisar'),
#  ('algún', 'algún'),
#  ('alacrán', 'alacrán'),
#  ('salido', 'salido'),
#  ('de', 'de'),
#  ('su', 'su'),
#  ('escondrijo', 'escondrijo'),
#  ('a', 'a'),
#  ('tomar', 'tomar'),
#  ('el', 'el'),
#  ('fresco', 'fresco'),
#  ('me', 'me'),
#  ('acerqué', 'acerqué'),
#  ('al', 'al'),
#  ('ventanillo', 'ventanillo'),
#  ('y', 'y'),
#  ('aspiré', 'aspiré'),
#  ('el', 'el'),
#  ('aire', 'aire'),
#  ('del', 'del'),
#  ('campo', 'campo'),
#  ('se', 'se'),
#  ('oía', 'oía'),
#  ('la', 'la'),
#  ('respiración', 'respiración'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('noche', 'noche'),
#  ('enorme', 'enorme'),
#  ('femenina', 'femenina'),
#  ('regresé', 'regresé'),
#  ('al', 'al'),
#  ('centro', 'centro'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('habitación', 'habitación'),
#  ('vacié', 'vacié'),
#  ('el', 'el'),
#  ('agua', 'agua'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('jarra', 'jarra'),
#  ('en', 'en'),
#  ('la', 'la'),
#  ('palangana', 'palangana'),
#  ('de', 'de'),
#  ('peltre', 'peltre'),
#  ('y', 'y'),
#  ('humedecí', 'humedecí'),
#  ('la', 'la'),
#  ('toalla', 'toalla'),
#  ('me', 'me'),
#  ('froté', 'froté'),
#  ('el', 'el'),
#  ('torso', 'torso'),
#  ('y', 'y'),
#  ('las', 'la'),
#  ('piernas', 'piernas'),
#  ('con', 'con'),
#  ('el', 'el'),
#  ('trapo', 'trapo'),
#  ('empapado', 'empapado'),
#  ('me', 'me'),
#  ('sequé', 'sequé'),
#  ('un', 'un'),
#  ('poco', 'poco'),
#  ('y', 'y'),
#  ('tras', 'tras'),
#  ('de', 'de'),
#  ('cerciorarme', 'cerciorarme'),
#  ('que', 'que'),
#  ('ningún', 'ningún'),
#  ('bicho', 'bicho'),
#  ('estaba', 'estaba'),
#  ('escondido', 'escondido'),
#  ('entre', 'entre'),
#  ('los', 'los'),
#  ('pliegues', 'pliegues'),
#  ('de', 'de'),
#  ('mi', 'mi'),
#  ('ropa', 'ropa'),
#  ('me', 'me'),
#  ('vestí', 'vestí'),
#  ('y', 'y'),
#  ('calcé', 'calcé'),
#  ('bajé', 'bajé'),
#  ('saltando', 'saltando'),
#  ('la', 'la'),
#  ('escalera', 'escalera'),
#  ('pintada', 'pintada'),
#  ('de', 'de'),
#  ('verde', 'verde'),
#  ('en', 'en'),
#  ('la', 'la'),
#  ('puerta', 'puerta'),
#  ('del', 'del'),
#  ('mesón', 'mesón'),
#  ('tropecé', 'tropecé'),
#  ('con', 'con'),
#  ('el', 'el'),
#  ('dueño', 'dueño'),
#  ('sujeto', 'sujeto'),
#  ('tuerto', 'tuerto'),
#  ('y', 'y'),
#  ('reticente', 'reticente'),
#  ('sentado', 'sentado'),
#  ('en', 'en'),
#  ('una', 'una'),
#  ('sillita', 'sillita'),
#  ('de', 'de'),
#  ('tule', 'tule'),
#  ('fumaba', 'fumaba'),
#  ('con', 'con'),
#  ('el', 'el'),
#  ('ojo', 'ojo'),
#  ('entrecerrado', 'entrecerrado'),
#  ('con', 'con'),
#  ('voz', 'voz'),
#  ('ronca', 'ronca'),
#  ('me', 'me'),
#  ('preguntó', 'preguntó'),
#  ('dónde', 'dónde'),
#  ('va', 'va'),
#  ('señor', 'señor'),
#  ('a', 'a'),
#  ('dar', 'dar'),
#  ('una', 'una'),
#  ('vuelta', 'vuelta'),
#  ('hace', 'hace'),
#  ('mucho', 'mucho'),
#  ('calor', 'calor'),
#  ('hum', 'hum'),
#  ('todo', 'todo'),
#  ('está', 'está'),
#  ('ya', 'ya'),
#  ('cerrado', 'cerrado'),
#  ('y', 'y'),
#  ('no', 'no'),
#  ('hay', 'hay'),
#  ('alumbrado', 'alumbrado'),
#  ('aquí', 'aquí'),
#  ('más', 'más'),
#  ('le', 'le'),
#  ('valiera', 'valiera'),
#  ('quedarse', 'quedarse'),
#  ('alcé', 'alcé'),
#  ('los', 'los'),
#  ('hombros', 'hombros'),
#  ('musité', 'musité'),
#  ('ahora', 'ahora'),
#  ('vuelvo', 'vuelvo'),
#  ('y', 'y'),
#  ('me', 'me'),
#  ('metí', 'metí'),
#  ('en', 'en'),
#  ('lo', 'lo'),
#  ('oscuro', 'oscuro'),
#  ('al', 'al'),
#  ('principio', 'principio'),
#  ('no', 'no'),
#  ('veía', 'veía'),
#  ('nada', 'nada'),
#  ('caminé', 'caminé'),
#  ('a', 'a'),
#  ('tientas', 'tientas'),
#  ('por', 'por'),
#  ('la', 'la'),
#  ('calle', 'calle'),
#  ('empedrada', 'empedrada'),
#  ('encendí', 'encendí'),
#  ('un', 'un'),
#  ('cigarrillo', 'cigarrillo'),
#  ('de', 'de'),
#  ('pronto', 'pronto'),
#  ('salió', 'salió'),
#  ('la', 'la'),
#  ('luna', 'luna'),
#  ('de', 'de'),
#  ('una', 'una'),
#  ('nube', 'nube'),
#  ('negra', 'negra'),
#  ('iluminando', 'iluminando'),
#  ('un', 'un'),
#  ('muro', 'muro'),
#  ('blanco', 'blanco'),
#  ('desmoronado', 'desmoronado'),
#  ('a', 'a'),
#  ('trechos', 'trechos'),
#  ('me', 'me'),
#  ('detuve', 'detuve'),
#  ('ciego', 'ciego'),
#  ('ante', 'ante'),
#  ('tanta', 'tanta'),
#  ('blancura', 'blancura'),
#  ('sopló', 'sopló'),
#  ('un', 'un'),
#  ('poco', 'poco'),
#  ('de', 'de'),
#  ('viento', 'viento'),
#  ('respiré', 'respiré'),
#  ('el', 'el'),
#  ('aire', 'aire'),
#  ('de', 'de'),
#  ('los', 'los'),
#  ('tamarindos', 'tamarindo'),
#  ('vibraba', 'vibraba'),
#  ('la', 'la'),
#  ('noche', 'noche'),
#  ('llena', 'llena'),
#  ('de', 'de'),
#  ('hojas', 'hojas'),
#  ('e', 'e'),
#  ('insectos', 'insectos'),
#  ('los', 'los'),
#  ('grillos', 'grillos'),
#  ('vivaqueaban', 'vivaqueaban'),
#  ('entre', 'entre'),
#  ('las', 'la'),
#  ('hierbas', 'hierbas'),
#  ('altas', 'altas'),
#  ('alcé', 'alcé'),
#  ('la', 'la'),
#  ('cara', 'cara'),
#  ('arriba', 'arriba'),
#  ('también', 'también'),
#  ('habían', 'habían'),
#  ('establecido', 'establecido'),
#  ('campamento', 'campamento'),
#  ('las', 'la'),
#  ('estrellas', 'estrellas'),
#  ('pensé', 'pensé'),
#  ('que', 'que'),
#  ('el', 'el'),
#  ('universo', 'universo'),
#  ('era', 'era'),
#  ('un', 'un'),
#  ('vasto', 'vasto'),
#  ('sistema', 'sistema'),
#  ('de', 'de'),
#  ('señales', 'señales'),
#  ('una', 'una'),
#  ('conversación', 'conversación'),
#  ('entre', 'entre'),
#  ('seres', 'seres'),
#  ('inmensos', 'inmensos'),
#  ('mis', 'mi'),
#  ('actos', 'actos'),
#  ('el', 'el'),
#  ('serrucho', 'serrucho'),
#  ('del', 'del'),
#  ('grillo', 'grillo'),
#  ('el', 'el'),
#  ('parpadeo', 'parpadeo'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('estrella', 'estrella'),
#  ('no', 'no'),
#  ('eran', 'eran'),
#  ('sino', 'sino'),
#  ('pausas', 'pausas'),
#  ('y', 'y'),
#  ('sílabas', 'sílabas'),
#  ('frases', 'frases'),
#  ('dispersas', 'dispersas'),
#  ('de', 'de'),
#  ('aquel', 'aquel'),
#  ('diálogo', 'diálogo'),
#  ('cuál', 'cuál'),
#  ('sería', 'sería'),
#  ('esa', 'esa'),
#  ('palabra', 'palabra'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('cual', 'cual'),
#  ('yo', 'yo'),
#  ('era', 'era'),
#  ('una', 'una'),
#  ('sílaba', 'sílaba'),
#  ('quién', 'quién'),
#  ('dice', 'dice'),
#  ('esa', 'esa'),
#  ('palabra', 'palabra'),
#  ('y', 'y'),
#  ('a', 'a'),
#  ('quién', 'quién'),
#  ('se', 'se'),
#  ('la', 'la'),
#  ('dice', 'dice'),
#  ('tiré', 'tiré'),
#  ('el', 'el'),
#  ('cigarrillo', 'cigarrillo'),
#  ('sobre', 'sobre'),
#  ('la', 'la'),
#  ('banqueta', 'banqueta'),
#  ('al', 'al'),
#  ('caer', 'caer'),
#  ('describió', 'describió'),
#  ('una', 'una'),
#  ('curva', 'curva'),
#  ('luminosa', 'luminosa'),
#  ('arrojando', 'arrojando'),
#  ('breves', 'breve'),
#  ('chispas', 'chispas'),
#  ('como', 'como'),
#  ('un', 'un'),
#  ('cometa', 'cometa'),
#  ('minúsculo', 'minúsculo'),
#  ('caminé', 'caminé'),
#  ('largo', 'largo'),
#  ('rato', 'rato'),
#  ('despacio', 'despacio'),
#  ('me', 'me'),
#  ('sentía', 'sentía'),
#  ('libre', 'libre'),
#  ('seguro', 'seguro'),
#  ('entre', 'entre'),
#  ('los', 'los'),
#  ('labios', 'labios'),
#  ('que', 'que'),
#  ('en', 'en'),
#  ('ese', 'ese'),
#  ('momento', 'momento'),
#  ('me', 'me'),
#  ('pronunciaban', 'pronunciaban'),
#  ('con', 'con'),
#  ('tanta', 'tanta'),
#  ('felicidad', 'felicidad'),
#  ('la', 'la'),
#  ('noche', 'noche'),
#  ('era', 'era'),
#  ('un', 'un'),
#  ('jardín', 'jardín'),
#  ('de', 'de'),
#  ('ojos', 'ojos'),
#  ('al', 'al'),
#  ('cruzar', 'cruzar'),
#  ('la', 'la'),
#  ('calle', 'calle'),
#  ('sentí', 'sentí'),
#  ('que', 'que'),
#  ('alguien', 'alguien'),
#  ('se', 'se'),
#  ('desprendía', 'desprendía'),
#  ('de', 'de'),
#  ('una', 'una'),
#  ('puerta', 'puerta'),
#  ('me', 'me'),
#  ('volví', 'volví'),
#  ('pero', 'pero'),
#  ('no', 'no'),
#  ('acerté', 'acerté'),
#  ('a', 'a'),
#  ('distinguir', 'distinguir'),
#  ('nada', 'nada'),
#  ('apreté', 'apreté'),
#  ('el', 'el'),
#  ('paso', 'paso'),
#  ('unos', 'unos'),
#  ('instantes', 'instantes'),
#  ('percibí', 'percibí'),
#  ('unos', 'unos'),
#  ('huaraches', 'huarache'),
#  ('sobre', 'sobre'),
#  ('las', 'la'),
#  ('piedras', 'piedras'),
#  ('calientes', 'calientes'),
#  ('no', 'no'),
#  ('quise', 'quise'),
#  ('volverme', 'volverme'),
#  ('aunque', 'aunque'),
#  ('sentía', 'sentía'),
#  ('que', 'que'),
#  ('la', 'la'),
#  ('sombra', 'sombra'),
#  ('se', 'se'),
#  ('acercaba', 'acercaba'),
#  ('cada', 'cada'),
#  ('vez', 'vez'),
#  ('más', 'más'),
#  ('intenté', 'intenté'),
#  ('correr', 'correr'),
#  ('no', 'no'),
#  ('pude', 'pude'),
#  ('me', 'me'),
#  ('detuve', 'detuve'),
#  ('en', 'en'),
#  ('seco', 'seco'),
#  ('bruscamente', 'bruscamente'),
#  ('antes', 'ante'),
#  ('de', 'de'),
#  ('que', 'que'),
#  ('pudiese', 'pudiese'),
#  ('defenderme', 'defenderme'),
#  ('sentí', 'sentí'),
#  ('la', 'la'),
#  ('punta', 'punta'),
#  ('de', 'de'),
#  ('un', 'un'),
#  ('cuchillo', 'cuchillo'),
#  ('en', 'en'),
#  ('mi', 'mi'),
#  ('espalda', 'espalda'),
#  ('y', 'y'),
#  ('una', 'una'),
#  ('voz', 'voz'),
#  ('dulce', 'dulce'),
#  ('no', 'no'),
#  ('se', 'se'),
#  ('mueva', 'mueva'),
#  ('señor', 'señor'),
#  ('o', 'o'),
#  ('se', 'se'),
#  ('lo', 'lo'),
#  ('entierro', 'entierro'),
#  ('sin', 'sin'),
#  ('volver', 'volver'),
#  ('la', 'la'),
#  ('cara', 'cara'),
#  ('pregunté', 'pregunté'),
#  ('qué', 'qué'),
#  ('quieres', 'quieres'),
#  ('sus', 'sus'),
#  ('ojos', 'ojos'),
#  ('señor', 'señor'),
#  ('contestó', 'contestó'),
#  ('la', 'la'),
#  ('voz', 'voz'),
#  ('suave', 'suave'),
#  ('casi', 'casi'),
#  ('apenada', 'apenada'),
#  ('mis', 'mi'),
#  ('ojos', 'ojos'),
#  ('para', 'para'),
#  ('qué', 'qué'),
#  ('te', 'te'),
#  ('servirán', 'servirán'),
#  ('mis', 'mi'),
#  ('ojos', 'ojos'),
#  ('mira', 'mira'),
#  ('aquí', 'aquí'),
#  ('tengo', 'tengo'),
#  ('un', 'un'),
#  ('poco', 'poco'),
#  ('de', 'de'),
#  ('dinero', 'dinero'),
#  ('no', 'no'),
#  ('es', 'e'),
#  ('mucho', 'mucho'),
#  ('pero', 'pero'),
#  ('es', 'e'),
#  ('algo', 'algo'),
#  ('te', 'te'),
#  ('daré', 'daré'),
#  ('todo', 'todo'),
#  ('lo', 'lo'),
#  ('que', 'que'),
#  ('tengo', 'tengo'),
#  ('si', 'si'),
#  ('me', 'me'),
#  ('dejas', 'dejas'),
#  ('no', 'no'),
#  ('vayas', 'vayas'),
#  ('a', 'a'),
#  ('matarme', 'matarme'),
#  ('no', 'no'),
#  ('tenga', 'tenga'),
#  ('miedo', 'miedo'),
#  ('señor', 'señor'),
#  ('no', 'no'),
#  ('lo', 'lo'),
#  ('mataré', 'mataré'),
#  ('nada', 'nada'),
#  ('más', 'más'),
#  ('voy', 'voy'),
#  ('a', 'a'),
#  ('sacarle', 'sacarle'),
#  ('los', 'los'),
#  ('ojos', 'ojos'),
#  ('pero', 'pero'),
#  ('para', 'para'),
#  ('qué', 'qué'),
#  ('quieres', 'quieres'),
#  ('mis', 'mi'),
#  ('ojos', 'ojos'),
#  ('es', 'e'),
#  ('un', 'un'),
#  ('capricho', 'capricho'),
#  ('de', 'de'),
#  ('mi', 'mi'),
#  ('novia', 'novia'),
#  ('quiere', 'quiere'),
#  ('un', 'un'),
#  ('ramito', 'ramito'),
#  ('de', 'de'),
#  ('ojos', 'ojos'),
#  ('azules', 'azules'),
#  ('y', 'y'),
#  ('por', 'por'),
#  ('aquí', 'aquí'),
#  ('hay', 'hay'),
#  ('pocos', 'pocos'),
#  ('que', 'que'),
#  ('los', 'los'),
#  ('tengan', 'tengan'),
#  ('mis', 'mi'),
#  ('ojos', 'ojos'),
#  ('no', 'no'),
#  ('te', 'te'),
#  ('sirven', 'sirven'),
#  ('no', 'no'),
#  ('son', 'son'),
#  ('azules', 'azules'),
#  ('sino', 'sino'),
#  ('amarillos', 'amarillo'),
#  ('ay', 'ay'),
#  ('señor', 'señor'),
#  ('no', 'no'),
#  ('quiera', 'quiera'),
#  ('engañarme', 'engañarme'),
#  ('bien', 'bien'),
#  ('sé', 'sé'),
#  ('que', 'que'),
#  ('los', 'los'),
#  ('tiene', 'tiene'),
#  ('azules', 'azules'),
#  ('no', 'no'),
#  ('se', 'se'),
#  ('le', 'le'),
#  ('sacan', 'sacan'),
#  ('a', 'a'),
#  ('un', 'un'),
#  ('cristiano', 'cristiano'),
#  ('los', 'los'),
#  ('ojos', 'ojos'),
#  ('así', 'así'),
#  ('te', 'te'),
#  ('daré', 'daré'),
#  ('otra', 'otra'),
#  ('cosa', 'cosa'),
#  ('no', 'no'),
#  ('se', 'se'),
#  ('haga', 'haga'),
#  ('el', 'el'),
#  ('remilgoso', 'remilgoso'),
#  ('me', 'me'),
#  ('dijo', 'dijo'),
#  ('con', 'con'),
#  ('dureza', 'dureza'),
#  ('dé', 'dé'),
#  ('la', 'la'),
#  ('vuelta', 'vuelta'),
#  ('me', 'me'),
#  ('volví', 'volví'),
#  ('era', 'era'),
#  ('pequeño', 'pequeño'),
#  ('y', 'y'),
#  ('frágil', 'frágil'),
#  ('el', 'el'),
#  ('sombrero', 'sombrero'),
#  ('de', 'de'),
#  ('palma', 'palma'),
#  ('le', 'le'),
#  ('cubría', 'cubría'),
#  ('medio', 'medio'),
#  ('rostro', 'rostro'),
#  ('sostenía', 'sostenía'),
#  ('con', 'con'),
#  ('el', 'el'),
#  ('brazo', 'brazo'),
#  ('derecho', 'derecho'),
#  ('un', 'un'),
#  ('machete', 'machete'),
#  ('de', 'de'),
#  ('campo', 'campo'),
#  ('que', 'que'),
#  ('brillaba', 'brillaba'),
#  ('con', 'con'),
#  ('la', 'la'),
#  ('luz', 'luz'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('luna', 'luna'),
#  ('alúmbrese', 'alúmbrese'),
#  ('la', 'la'),
#  ('cara', 'cara'),
#  ('encendí', 'encendí'),
#  ('y', 'y'),
#  ('me', 'me'),
#  ('acerqué', 'acerqué'),
#  ('la', 'la'),
#  ('llama', 'llama'),
#  ('al', 'al'),
#  ('rostro', 'rostro'),
#  ('el', 'el'),
#  ('resplandor', 'resplandor'),
#  ('me', 'me'),
#  ('hizo', 'hizo'),
#  ('entrecerrar', 'entrecerrar'),
#  ('los', 'los'),
#  ('ojos', 'ojos'),
#  ('el', 'el'),
#  ('apartó', 'apartó'),
#  ('mis', 'mi'),
#  ('párpados', 'párpados'),
#  ('con', 'con'),
#  ('mano', 'mano'),
#  ('firme', 'firme'),
#  ('no', 'no'),
#  ('podía', 'podía'),
#  ('ver', 'ver'),
#  ('bien', 'bien'),
#  ('se', 'se'),
#  ('alzó', 'alzó'),
#  ('sobre', 'sobre'),
#  ('las', 'la'),
#  ('puntas', 'puntas'),
#  ('de', 'de'),
#  ('los', 'los'),
#  ('pies', 'pie'),
#  ('y', 'y'),
#  ('me', 'me'),
#  ('contempló', 'contempló'),
#  ('intensamente', 'intensamente'),
#  ('la', 'la'),
#  ('llama', 'llama'),
#  ('me', 'me'),
#  ('quemaba', 'quemaba'),
#  ('los', 'los'),
#  ('dedos', 'dedos'),
#  ('la', 'la'),
#  ('arrojé', 'arrojé'),
#  ('permaneció', 'permaneció'),
#  ('un', 'un'),
#  ('instante', 'instante'),
#  ('silencioso', 'silencioso'),
#  ('ya', 'ya'),
#  ('te', 'te'),
#  ('convenciste', 'convenciste'),
#  ('no', 'no'),
#  ('los', 'los'),
#  ('tengo', 'tengo'),
#  ('azules', 'azules'),
#  ('ah', 'ah'),
#  ('qué', 'qué'),
#  ('mañoso', 'mañoso'),
#  ('es', 'e'),
#  ('usted', 'usted'),
#  ('respondió', 'respondió'),
#  ('a', 'a'),
#  ('ver', 'ver'),
#  ('encienda', 'encienda'),
#  ('otra', 'otra'),
#  ('vez', 'vez'),
#  ('froté', 'froté'),
#  ('otro', 'otro'),
#  ('fósforo', 'fósforo'),
#  ('y', 'y'),
#  ('lo', 'lo'),
#  ('acerqué', 'acerqué'),
#  ('a', 'a'),
#  ('mis', 'mi'),
#  ('ojos', 'ojos'),
#  ('tirándome', 'tirándome'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('manga', 'manga'),
#  ('me', 'me'),
#  ('ordenó', 'ordenó'),
#  ('arrodíllese', 'arrodíllese'),
#  ('mi', 'mi'),
#  ('hinqué', 'hinqué'),
#  ('con', 'con'),
#  ('una', 'una'),
#  ('mano', 'mano'),
#  ('me', 'me'),
#  ('cogió', 'cogió'),
#  ('por', 'por'),
#  ('los', 'los'),
#  ('cabellos', 'cabellos'),
#  ('echándome', 'echándome'),
#  ('la', 'la'),
#  ('cabeza', 'cabeza'),
#  ('hacia', 'hacia'),
#  ('atrás', 'atrás'),
#  ('se', 'se'),
#  ('inclinó', 'inclinó'),
#  ('sobre', 'sobre'),
#  ('mí', 'mí'),
#  ('curioso', 'curioso'),
#  ('y', 'y'),
#  ('tenso', 'tenso'),
#  ('mientras', 'mientras'),
#  ('el', 'el'),
#  ('machete', 'machete'),
#  ('descendía', 'descendía'),
#  ('lentamente', 'lentamente'),
#  ('hasta', 'hasta'),
#  ('rozar', 'rozar'),
#  ('mis', 'mi'),
#  ('párpados', 'párpados'),
#  ('cerré', 'cerré'),
#  ('los', 'los'),
#  ('ojos', 'ojos'),
#  ('ábralos', 'ábralos'),
#  ('bien', 'bien'),
#  ('ordenó', 'ordenó'),
#  ('abrí', 'abrí'),
#  ('los', 'los'),
#  ('ojos', 'ojos'),
#  ('la', 'la'),
#  ('llamita', 'llamita'),
#  ('me', 'me'),
#  ('quemaba', 'quemaba'),
#  ('las', 'la'),
#  ('pestañas', 'pestañas'),
#  ('me', 'me'),
#  ('soltó', 'soltó'),
#  ('de', 'de'),
#  ('improviso', 'improviso'),
#  ('pues', 'pues'),
#  ('no', 'no'),
#  ('son', 'son'),
#  ('azules', 'azules'),
#  ('señor', 'señor'),
#  ('dispense', 'dispense'),
#  ('y', 'y'),
#  ('despareció', 'despareció'),
#  ('me', 'me'),
#  ('acodé', 'acodé'),
#  ('junto', 'junto'),
#  ('al', 'al'),
#  ('muro', 'muro'),
#  ('con', 'con'),
#  ('la', 'la'),
#  ('cabeza', 'cabeza'),
#  ('entre', 'entre'),
#  ('las', 'la'),
#  ('manos', 'manos'),
#  ('luego', 'luego'),
#  ('me', 'me'),
#  ('incorporé', 'incorporé'),
#  ('a', 'a'),
#  ('tropezones', 'tropezones'),
#  ('cayendo', 'cayendo'),
#  ('y', 'y'),
#  ('levantándome', 'levantándome'),
#  ('corrí', 'corrí'),
#  ('durante', 'durante'),
#  ('una', 'una'),
#  ('hora', 'hora'),
#  ('por', 'por'),
#  ('el', 'el'),
#  ('pueblo', 'pueblo'),
#  ('desierto', 'desierto'),
#  ('cuando', 'cuando'),
#  ('llegué', 'llegué'),
#  ('a', 'a'),
#  ('la', 'la'),
#  ('plaza', 'plaza'),
#  ('vi', 'vi'),
#  ('al', 'al'),
#  ('dueño', 'dueño'),
#  ('del', 'del'),
#  ('mesón', 'mesón'),
#  ('sentado', 'sentado'),
#  ('aún', 'aún'),
#  ('frente', 'frente'),
#  ('a', 'a'),
#  ('la', 'la'),
#  ('puerta', 'puerta'),
#  ('entré', 'entré'),
#  ('sin', 'sin'),
#  ('decir', 'decir'),
#  ('palabra', 'palabra'),
#  ('al', 'al'),
#  ('día', 'día'),
#  ('siguiente', 'siguiente'),
#  ('huí', 'huí'),
#  ('de', 'de'),
#  ('aquel', 'aquel'),
#  ('pueblo', 'pueblo')]

# %%
# Inicializamos el algoritmo de Porter (para realizar el stemming) 
porter = nltk.PorterStemmer()
# Obtenemos la raíz de cada token (cada palabra) en lista por comprensión
raiz = [(t,porter.stem(t)) for t in tokens]
raiz
# Out:
# [('el', 'el'),
#  ('ramo', 'ramo'),
#  ('azul', 'azul'),
#  ('un', 'un'),
#  ('cuento', 'cuento'),
#  ('de', 'de'),
#  ('octavio', 'octavio'),
#  ('paz', 'paz'),
#  ('desperté', 'desperté'),
#  ('cubierto', 'cubierto'),
#  ('de', 'de'),
#  ('sudor', 'sudor'),
#  ('del', 'del'),
#  ('piso', 'piso'),
#  ('de', 'de'),
#  ('ladrillos', 'ladrillo'),
#  ('rojos', 'rojo'),
#  ('recién', 'recién'),
#  ('regados', 'regado'),
#  ('subía', 'subía'),
#  ('un', 'un'),
#  ('vapor', 'vapor'),
#  ('caliente', 'calient'),
#  ('una', 'una'),
#  ('mariposa', 'mariposa'),
#  ('de', 'de'),
#  ('alas', 'ala'),
#  ('grisáceas', 'grisácea'),
#  ('revoloteaba', 'revoloteaba'),
#  ('encandilada', 'encandilada'),
#  ('alrededor', 'alrededor'),
#  ('del', 'del'),
#  ('foco', 'foco'),
#  ('amarillento', 'amarillento'),
#  ('salté', 'salté'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('hamaca', 'hamaca'),
#  ('y', 'y'),
#  ('descalzo', 'descalzo'),
#  ('atravesé', 'atravesé'),
#  ('el', 'el'),
#  ('cuarto', 'cuarto'),
#  ('cuidando', 'cuidando'),
#  ('no', 'no'),
#  ('pisar', 'pisar'),
#  ('algún', 'algún'),
#  ('alacrán', 'alacrán'),
#  ('salido', 'salido'),
#  ('de', 'de'),
#  ('su', 'su'),
#  ('escondrijo', 'escondrijo'),
#  ('a', 'a'),
#  ('tomar', 'tomar'),
#  ('el', 'el'),
#  ('fresco', 'fresco'),
#  ('me', 'me'),
#  ('acerqué', 'acerqué'),
#  ('al', 'al'),
#  ('ventanillo', 'ventanillo'),
#  ('y', 'y'),
#  ('aspiré', 'aspiré'),
#  ('el', 'el'),
#  ('aire', 'air'),
#  ('del', 'del'),
#  ('campo', 'campo'),
#  ('se', 'se'),
#  ('oía', 'oía'),
#  ('la', 'la'),
#  ('respiración', 'respiración'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('noche', 'noch'),
#  ('enorme', 'enorm'),
#  ('femenina', 'femenina'),
#  ('regresé', 'regresé'),
#  ('al', 'al'),
#  ('centro', 'centro'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('habitación', 'habitación'),
#  ('vacié', 'vacié'),
#  ('el', 'el'),
#  ('agua', 'agua'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('jarra', 'jarra'),
#  ('en', 'en'),
#  ('la', 'la'),
#  ('palangana', 'palangana'),
#  ('de', 'de'),
#  ('peltre', 'peltr'),
#  ('y', 'y'),
#  ('humedecí', 'humedecí'),
#  ('la', 'la'),
#  ('toalla', 'toalla'),
#  ('me', 'me'),
#  ('froté', 'froté'),
#  ('el', 'el'),
#  ('torso', 'torso'),
#  ('y', 'y'),
#  ('las', 'la'),
#  ('piernas', 'pierna'),
#  ('con', 'con'),
#  ('el', 'el'),
#  ('trapo', 'trapo'),
#  ('empapado', 'empapado'),
#  ('me', 'me'),
#  ('sequé', 'sequé'),
#  ('un', 'un'),
#  ('poco', 'poco'),
#  ('y', 'y'),
#  ('tras', 'tra'),
#  ('de', 'de'),
#  ('cerciorarme', 'cerciorarm'),
#  ('que', 'que'),
#  ('ningún', 'ningún'),
#  ('bicho', 'bicho'),
#  ('estaba', 'estaba'),
#  ('escondido', 'escondido'),
#  ('entre', 'entr'),
#  ('los', 'lo'),
#  ('pliegues', 'pliegu'),
#  ('de', 'de'),
#  ('mi', 'mi'),
#  ('ropa', 'ropa'),
#  ('me', 'me'),
#  ('vestí', 'vestí'),
#  ('y', 'y'),
#  ('calcé', 'calcé'),
#  ('bajé', 'bajé'),
#  ('saltando', 'saltando'),
#  ('la', 'la'),
#  ('escalera', 'escalera'),
#  ('pintada', 'pintada'),
#  ('de', 'de'),
#  ('verde', 'verd'),
#  ('en', 'en'),
#  ('la', 'la'),
#  ('puerta', 'puerta'),
#  ('del', 'del'),
#  ('mesón', 'mesón'),
#  ('tropecé', 'tropecé'),
#  ('con', 'con'),
#  ('el', 'el'),
#  ('dueño', 'dueño'),
#  ('sujeto', 'sujeto'),
#  ('tuerto', 'tuerto'),
#  ('y', 'y'),
#  ('reticente', 'reticent'),
#  ('sentado', 'sentado'),
#  ('en', 'en'),
#  ('una', 'una'),
#  ('sillita', 'sillita'),
#  ('de', 'de'),
#  ('tule', 'tule'),
#  ('fumaba', 'fumaba'),
#  ('con', 'con'),
#  ('el', 'el'),
#  ('ojo', 'ojo'),
#  ('entrecerrado', 'entrecerrado'),
#  ('con', 'con'),
#  ('voz', 'voz'),
#  ('ronca', 'ronca'),
#  ('me', 'me'),
#  ('preguntó', 'preguntó'),
#  ('dónde', 'dónde'),
#  ('va', 'va'),
#  ('señor', 'señor'),
#  ('a', 'a'),
#  ('dar', 'dar'),
#  ('una', 'una'),
#  ('vuelta', 'vuelta'),
#  ('hace', 'hace'),
#  ('mucho', 'mucho'),
#  ('calor', 'calor'),
#  ('hum', 'hum'),
#  ('todo', 'todo'),
#  ('está', 'está'),
#  ('ya', 'ya'),
#  ('cerrado', 'cerrado'),
#  ('y', 'y'),
#  ('no', 'no'),
#  ('hay', 'hay'),
#  ('alumbrado', 'alumbrado'),
#  ('aquí', 'aquí'),
#  ('más', 'má'),
#  ('le', 'le'),
#  ('valiera', 'valiera'),
#  ('quedarse', 'quedars'),
#  ('alcé', 'alcé'),
#  ('los', 'lo'),
#  ('hombros', 'hombro'),
#  ('musité', 'musité'),
#  ('ahora', 'ahora'),
#  ('vuelvo', 'vuelvo'),
#  ('y', 'y'),
#  ('me', 'me'),
#  ('metí', 'metí'),
#  ('en', 'en'),
#  ('lo', 'lo'),
#  ('oscuro', 'oscuro'),
#  ('al', 'al'),
#  ('principio', 'principio'),
#  ('no', 'no'),
#  ('veía', 'veía'),
#  ('nada', 'nada'),
#  ('caminé', 'caminé'),
#  ('a', 'a'),
#  ('tientas', 'tienta'),
#  ('por', 'por'),
#  ('la', 'la'),
#  ('calle', 'call'),
#  ('empedrada', 'empedrada'),
#  ('encendí', 'encendí'),
#  ('un', 'un'),
#  ('cigarrillo', 'cigarrillo'),
#  ('de', 'de'),
#  ('pronto', 'pronto'),
#  ('salió', 'salió'),
#  ('la', 'la'),
#  ('luna', 'luna'),
#  ('de', 'de'),
#  ('una', 'una'),
#  ('nube', 'nube'),
#  ('negra', 'negra'),
#  ('iluminando', 'iluminando'),
#  ('un', 'un'),
#  ('muro', 'muro'),
#  ('blanco', 'blanco'),
#  ('desmoronado', 'desmoronado'),
#  ('a', 'a'),
#  ('trechos', 'trecho'),
#  ('me', 'me'),
#  ('detuve', 'detuv'),
#  ('ciego', 'ciego'),
#  ('ante', 'ant'),
#  ('tanta', 'tanta'),
#  ('blancura', 'blancura'),
#  ('sopló', 'sopló'),
#  ('un', 'un'),
#  ('poco', 'poco'),
#  ('de', 'de'),
#  ('viento', 'viento'),
#  ('respiré', 'respiré'),
#  ('el', 'el'),
#  ('aire', 'air'),
#  ('de', 'de'),
#  ('los', 'lo'),
#  ('tamarindos', 'tamarindo'),
#  ('vibraba', 'vibraba'),
#  ('la', 'la'),
#  ('noche', 'noch'),
#  ('llena', 'llena'),
#  ('de', 'de'),
#  ('hojas', 'hoja'),
#  ('e', 'e'),
#  ('insectos', 'insecto'),
#  ('los', 'lo'),
#  ('grillos', 'grillo'),
#  ('vivaqueaban', 'vivaqueaban'),
#  ('entre', 'entr'),
#  ('las', 'la'),
#  ('hierbas', 'hierba'),
#  ('altas', 'alta'),
#  ('alcé', 'alcé'),
#  ('la', 'la'),
#  ('cara', 'cara'),
#  ('arriba', 'arriba'),
#  ('también', 'también'),
#  ('habían', 'habían'),
#  ('establecido', 'establecido'),
#  ('campamento', 'campamento'),
#  ('las', 'la'),
#  ('estrellas', 'estrella'),
#  ('pensé', 'pensé'),
#  ('que', 'que'),
#  ('el', 'el'),
#  ('universo', 'universo'),
#  ('era', 'era'),
#  ('un', 'un'),
#  ('vasto', 'vasto'),
#  ('sistema', 'sistema'),
#  ('de', 'de'),
#  ('señales', 'señal'),
#  ('una', 'una'),
#  ('conversación', 'conversación'),
#  ('entre', 'entr'),
#  ('seres', 'sere'),
#  ('inmensos', 'inmenso'),
#  ('mis', 'mi'),
#  ('actos', 'acto'),
#  ('el', 'el'),
#  ('serrucho', 'serrucho'),
#  ('del', 'del'),
#  ('grillo', 'grillo'),
#  ('el', 'el'),
#  ('parpadeo', 'parpadeo'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('estrella', 'estrella'),
#  ('no', 'no'),
#  ('eran', 'eran'),
#  ('sino', 'sino'),
#  ('pausas', 'pausa'),
#  ('y', 'y'),
#  ('sílabas', 'sílaba'),
#  ('frases', 'frase'),
#  ('dispersas', 'dispersa'),
#  ('de', 'de'),
#  ('aquel', 'aquel'),
#  ('diálogo', 'diálogo'),
#  ('cuál', 'cuál'),
#  ('sería', 'sería'),
#  ('esa', 'esa'),
#  ('palabra', 'palabra'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('cual', 'cual'),
#  ('yo', 'yo'),
#  ('era', 'era'),
#  ('una', 'una'),
#  ('sílaba', 'sílaba'),
#  ('quién', 'quién'),
#  ('dice', 'dice'),
#  ('esa', 'esa'),
#  ('palabra', 'palabra'),
#  ('y', 'y'),
#  ('a', 'a'),
#  ('quién', 'quién'),
#  ('se', 'se'),
#  ('la', 'la'),
#  ('dice', 'dice'),
#  ('tiré', 'tiré'),
#  ('el', 'el'),
#  ('cigarrillo', 'cigarrillo'),
#  ('sobre', 'sobr'),
#  ('la', 'la'),
#  ('banqueta', 'banqueta'),
#  ('al', 'al'),
#  ('caer', 'caer'),
#  ('describió', 'describió'),
#  ('una', 'una'),
#  ('curva', 'curva'),
#  ('luminosa', 'luminosa'),
#  ('arrojando', 'arrojando'),
#  ('breves', 'breve'),
#  ('chispas', 'chispa'),
#  ('como', 'como'),
#  ('un', 'un'),
#  ('cometa', 'cometa'),
#  ('minúsculo', 'minúsculo'),
#  ('caminé', 'caminé'),
#  ('largo', 'largo'),
#  ('rato', 'rato'),
#  ('despacio', 'despacio'),
#  ('me', 'me'),
#  ('sentía', 'sentía'),
#  ('libre', 'libr'),
#  ('seguro', 'seguro'),
#  ('entre', 'entr'),
#  ('los', 'lo'),
#  ('labios', 'labio'),
#  ('que', 'que'),
#  ('en', 'en'),
#  ('ese', 'ese'),
#  ('momento', 'momento'),
#  ('me', 'me'),
#  ('pronunciaban', 'pronunciaban'),
#  ('con', 'con'),
#  ('tanta', 'tanta'),
#  ('felicidad', 'felicidad'),
#  ('la', 'la'),
#  ('noche', 'noch'),
#  ('era', 'era'),
#  ('un', 'un'),
#  ('jardín', 'jardín'),
#  ('de', 'de'),
#  ('ojos', 'ojo'),
#  ('al', 'al'),
#  ('cruzar', 'cruzar'),
#  ('la', 'la'),
#  ('calle', 'call'),
#  ('sentí', 'sentí'),
#  ('que', 'que'),
#  ('alguien', 'alguien'),
#  ('se', 'se'),
#  ('desprendía', 'desprendía'),
#  ('de', 'de'),
#  ('una', 'una'),
#  ('puerta', 'puerta'),
#  ('me', 'me'),
#  ('volví', 'volví'),
#  ('pero', 'pero'),
#  ('no', 'no'),
#  ('acerté', 'acerté'),
#  ('a', 'a'),
#  ('distinguir', 'distinguir'),
#  ('nada', 'nada'),
#  ('apreté', 'apreté'),
#  ('el', 'el'),
#  ('paso', 'paso'),
#  ('unos', 'uno'),
#  ('instantes', 'instant'),
#  ('percibí', 'percibí'),
#  ('unos', 'uno'),
#  ('huaraches', 'huarach'),
#  ('sobre', 'sobr'),
#  ('las', 'la'),
#  ('piedras', 'piedra'),
#  ('calientes', 'calient'),
#  ('no', 'no'),
#  ('quise', 'quis'),
#  ('volverme', 'volverm'),
#  ('aunque', 'aunqu'),
#  ('sentía', 'sentía'),
#  ('que', 'que'),
#  ('la', 'la'),
#  ('sombra', 'sombra'),
#  ('se', 'se'),
#  ('acercaba', 'acercaba'),
#  ('cada', 'cada'),
#  ('vez', 'vez'),
#  ('más', 'má'),
#  ('intenté', 'intenté'),
#  ('correr', 'correr'),
#  ('no', 'no'),
#  ('pude', 'pude'),
#  ('me', 'me'),
#  ('detuve', 'detuv'),
#  ('en', 'en'),
#  ('seco', 'seco'),
#  ('bruscamente', 'bruscament'),
#  ('antes', 'ant'),
#  ('de', 'de'),
#  ('que', 'que'),
#  ('pudiese', 'pudies'),
#  ('defenderme', 'defenderm'),
#  ('sentí', 'sentí'),
#  ('la', 'la'),
#  ('punta', 'punta'),
#  ('de', 'de'),
#  ('un', 'un'),
#  ('cuchillo', 'cuchillo'),
#  ('en', 'en'),
#  ('mi', 'mi'),
#  ('espalda', 'espalda'),
#  ('y', 'y'),
#  ('una', 'una'),
#  ('voz', 'voz'),
#  ('dulce', 'dulc'),
#  ('no', 'no'),
#  ('se', 'se'),
#  ('mueva', 'mueva'),
#  ('señor', 'señor'),
#  ('o', 'o'),
#  ('se', 'se'),
#  ('lo', 'lo'),
#  ('entierro', 'entierro'),
#  ('sin', 'sin'),
#  ('volver', 'volver'),
#  ('la', 'la'),
#  ('cara', 'cara'),
#  ('pregunté', 'pregunté'),
#  ('qué', 'qué'),
#  ('quieres', 'quier'),
#  ('sus', 'su'),
#  ('ojos', 'ojo'),
#  ('señor', 'señor'),
#  ('contestó', 'contestó'),
#  ('la', 'la'),
#  ('voz', 'voz'),
#  ('suave', 'suav'),
#  ('casi', 'casi'),
#  ('apenada', 'apenada'),
#  ('mis', 'mi'),
#  ('ojos', 'ojo'),
#  ('para', 'para'),
#  ('qué', 'qué'),
#  ('te', 'te'),
#  ('servirán', 'servirán'),
#  ('mis', 'mi'),
#  ('ojos', 'ojo'),
#  ('mira', 'mira'),
#  ('aquí', 'aquí'),
#  ('tengo', 'tengo'),
#  ('un', 'un'),
#  ('poco', 'poco'),
#  ('de', 'de'),
#  ('dinero', 'dinero'),
#  ('no', 'no'),
#  ('es', 'es'),
#  ('mucho', 'mucho'),
#  ('pero', 'pero'),
#  ('es', 'es'),
#  ('algo', 'algo'),
#  ('te', 'te'),
#  ('daré', 'daré'),
#  ('todo', 'todo'),
#  ('lo', 'lo'),
#  ('que', 'que'),
#  ('tengo', 'tengo'),
#  ('si', 'si'),
#  ('me', 'me'),
#  ('dejas', 'deja'),
#  ('no', 'no'),
#  ('vayas', 'vaya'),
#  ('a', 'a'),
#  ('matarme', 'matarm'),
#  ('no', 'no'),
#  ('tenga', 'tenga'),
#  ('miedo', 'miedo'),
#  ('señor', 'señor'),
#  ('no', 'no'),
#  ('lo', 'lo'),
#  ('mataré', 'mataré'),
#  ('nada', 'nada'),
#  ('más', 'má'),
#  ('voy', 'voy'),
#  ('a', 'a'),
#  ('sacarle', 'sacarl'),
#  ('los', 'lo'),
#  ('ojos', 'ojo'),
#  ('pero', 'pero'),
#  ('para', 'para'),
#  ('qué', 'qué'),
#  ('quieres', 'quier'),
#  ('mis', 'mi'),
#  ('ojos', 'ojo'),
#  ('es', 'es'),
#  ('un', 'un'),
#  ('capricho', 'capricho'),
#  ('de', 'de'),
#  ('mi', 'mi'),
#  ('novia', 'novia'),
#  ('quiere', 'quier'),
#  ('un', 'un'),
#  ('ramito', 'ramito'),
#  ('de', 'de'),
#  ('ojos', 'ojo'),
#  ('azules', 'azul'),
#  ('y', 'y'),
#  ('por', 'por'),
#  ('aquí', 'aquí'),
#  ('hay', 'hay'),
#  ('pocos', 'poco'),
#  ('que', 'que'),
#  ('los', 'lo'),
#  ('tengan', 'tengan'),
#  ('mis', 'mi'),
#  ('ojos', 'ojo'),
#  ('no', 'no'),
#  ('te', 'te'),
#  ('sirven', 'sirven'),
#  ('no', 'no'),
#  ('son', 'son'),
#  ('azules', 'azul'),
#  ('sino', 'sino'),
#  ('amarillos', 'amarillo'),
#  ('ay', 'ay'),
#  ('señor', 'señor'),
#  ('no', 'no'),
#  ('quiera', 'quiera'),
#  ('engañarme', 'engañarm'),
#  ('bien', 'bien'),
#  ('sé', 'sé'),
#  ('que', 'que'),
#  ('los', 'lo'),
#  ('tiene', 'tien'),
#  ('azules', 'azul'),
#  ('no', 'no'),
#  ('se', 'se'),
#  ('le', 'le'),
#  ('sacan', 'sacan'),
#  ('a', 'a'),
#  ('un', 'un'),
#  ('cristiano', 'cristiano'),
#  ('los', 'lo'),
#  ('ojos', 'ojo'),
#  ('así', 'así'),
#  ('te', 'te'),
#  ('daré', 'daré'),
#  ('otra', 'otra'),
#  ('cosa', 'cosa'),
#  ('no', 'no'),
#  ('se', 'se'),
#  ('haga', 'haga'),
#  ('el', 'el'),
#  ('remilgoso', 'remilgoso'),
#  ('me', 'me'),
#  ('dijo', 'dijo'),
#  ('con', 'con'),
#  ('dureza', 'dureza'),
#  ('dé', 'dé'),
#  ('la', 'la'),
#  ('vuelta', 'vuelta'),
#  ('me', 'me'),
#  ('volví', 'volví'),
#  ('era', 'era'),
#  ('pequeño', 'pequeño'),
#  ('y', 'y'),
#  ('frágil', 'frágil'),
#  ('el', 'el'),
#  ('sombrero', 'sombrero'),
#  ('de', 'de'),
#  ('palma', 'palma'),
#  ('le', 'le'),
#  ('cubría', 'cubría'),
#  ('medio', 'medio'),
#  ('rostro', 'rostro'),
#  ('sostenía', 'sostenía'),
#  ('con', 'con'),
#  ('el', 'el'),
#  ('brazo', 'brazo'),
#  ('derecho', 'derecho'),
#  ('un', 'un'),
#  ('machete', 'machet'),
#  ('de', 'de'),
#  ('campo', 'campo'),
#  ('que', 'que'),
#  ('brillaba', 'brillaba'),
#  ('con', 'con'),
#  ('la', 'la'),
#  ('luz', 'luz'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('luna', 'luna'),
#  ('alúmbrese', 'alúmbres'),
#  ('la', 'la'),
#  ('cara', 'cara'),
#  ('encendí', 'encendí'),
#  ('y', 'y'),
#  ('me', 'me'),
#  ('acerqué', 'acerqué'),
#  ('la', 'la'),
#  ('llama', 'llama'),
#  ('al', 'al'),
#  ('rostro', 'rostro'),
#  ('el', 'el'),
#  ('resplandor', 'resplandor'),
#  ('me', 'me'),
#  ('hizo', 'hizo'),
#  ('entrecerrar', 'entrecerrar'),
#  ('los', 'lo'),
#  ('ojos', 'ojo'),
#  ('el', 'el'),
#  ('apartó', 'apartó'),
#  ('mis', 'mi'),
#  ('párpados', 'párpado'),
#  ('con', 'con'),
#  ('mano', 'mano'),
#  ('firme', 'firm'),
#  ('no', 'no'),
#  ('podía', 'podía'),
#  ('ver', 'ver'),
#  ('bien', 'bien'),
#  ('se', 'se'),
#  ('alzó', 'alzó'),
#  ('sobre', 'sobr'),
#  ('las', 'la'),
#  ('puntas', 'punta'),
#  ('de', 'de'),
#  ('los', 'lo'),
#  ('pies', 'pie'),
#  ('y', 'y'),
#  ('me', 'me'),
#  ('contempló', 'contempló'),
#  ('intensamente', 'intensament'),
#  ('la', 'la'),
#  ('llama', 'llama'),
#  ('me', 'me'),
#  ('quemaba', 'quemaba'),
#  ('los', 'lo'),
#  ('dedos', 'dedo'),
#  ('la', 'la'),
#  ('arrojé', 'arrojé'),
#  ('permaneció', 'permaneció'),
#  ('un', 'un'),
#  ('instante', 'instant'),
#  ('silencioso', 'silencioso'),
#  ('ya', 'ya'),
#  ('te', 'te'),
#  ('convenciste', 'convencist'),
#  ('no', 'no'),
#  ('los', 'lo'),
#  ('tengo', 'tengo'),
#  ('azules', 'azul'),
#  ('ah', 'ah'),
#  ('qué', 'qué'),
#  ('mañoso', 'mañoso'),
#  ('es', 'es'),
#  ('usted', 'ust'),
#  ('respondió', 'respondió'),
#  ('a', 'a'),
#  ('ver', 'ver'),
#  ('encienda', 'encienda'),
#  ('otra', 'otra'),
#  ('vez', 'vez'),
#  ('froté', 'froté'),
#  ('otro', 'otro'),
#  ('fósforo', 'fósforo'),
#  ('y', 'y'),
#  ('lo', 'lo'),
#  ('acerqué', 'acerqué'),
#  ('a', 'a'),
#  ('mis', 'mi'),
#  ('ojos', 'ojo'),
#  ('tirándome', 'tirándom'),
#  ('de', 'de'),
#  ('la', 'la'),
#  ('manga', 'manga'),
#  ('me', 'me'),
#  ('ordenó', 'ordenó'),
#  ('arrodíllese', 'arrodílles'),
#  ('mi', 'mi'),
#  ('hinqué', 'hinqué'),
#  ('con', 'con'),
#  ('una', 'una'),
#  ('mano', 'mano'),
#  ('me', 'me'),
#  ('cogió', 'cogió'),
#  ('por', 'por'),
#  ('los', 'lo'),
#  ('cabellos', 'cabello'),
#  ('echándome', 'echándom'),
#  ('la', 'la'),
#  ('cabeza', 'cabeza'),
#  ('hacia', 'hacia'),
#  ('atrás', 'atrá'),
#  ('se', 'se'),
#  ('inclinó', 'inclinó'),
#  ('sobre', 'sobr'),
#  ('mí', 'mí'),
#  ('curioso', 'curioso'),
#  ('y', 'y'),
#  ('tenso', 'tenso'),
#  ('mientras', 'mientra'),
#  ('el', 'el'),
#  ('machete', 'machet'),
#  ('descendía', 'descendía'),
#  ('lentamente', 'lentament'),
#  ('hasta', 'hasta'),
#  ('rozar', 'rozar'),
#  ('mis', 'mi'),
#  ('párpados', 'párpado'),
#  ('cerré', 'cerré'),
#  ('los', 'lo'),
#  ('ojos', 'ojo'),
#  ('ábralos', 'ábralo'),
#  ('bien', 'bien'),
#  ('ordenó', 'ordenó'),
#  ('abrí', 'abrí'),
#  ('los', 'lo'),
#  ('ojos', 'ojo'),
#  ('la', 'la'),
#  ('llamita', 'llamita'),
#  ('me', 'me'),
#  ('quemaba', 'quemaba'),
#  ('las', 'la'),
#  ('pestañas', 'pestaña'),
#  ('me', 'me'),
#  ('soltó', 'soltó'),
#  ('de', 'de'),
#  ('improviso', 'improviso'),
#  ('pues', 'pue'),
#  ('no', 'no'),
#  ('son', 'son'),
#  ('azules', 'azul'),
#  ('señor', 'señor'),
#  ('dispense', 'dispens'),
#  ('y', 'y'),
#  ('despareció', 'despareció'),
#  ('me', 'me'),
#  ('acodé', 'acodé'),
#  ('junto', 'junto'),
#  ('al', 'al'),
#  ('muro', 'muro'),
#  ('con', 'con'),
#  ('la', 'la'),
#  ('cabeza', 'cabeza'),
#  ('entre', 'entr'),
#  ('las', 'la'),
#  ('manos', 'mano'),
#  ('luego', 'luego'),
#  ('me', 'me'),
#  ('incorporé', 'incorporé'),
#  ('a', 'a'),
#  ('tropezones', 'tropezon'),
#  ('cayendo', 'cayendo'),
#  ('y', 'y'),
#  ('levantándome', 'levantándom'),
#  ('corrí', 'corrí'),
#  ('durante', 'durant'),
#  ('una', 'una'),
#  ('hora', 'hora'),
#  ('por', 'por'),
#  ('el', 'el'),
#  ('pueblo', 'pueblo'),
#  ('desierto', 'desierto'),
#  ('cuando', 'cuando'),
#  ('llegué', 'llegué'),
#  ('a', 'a'),
#  ('la', 'la'),
#  ('plaza', 'plaza'),
#  ('vi', 'vi'),
#  ('al', 'al'),
#  ('dueño', 'dueño'),
#  ('del', 'del'),
#  ('mesón', 'mesón'),
#  ('sentado', 'sentado'),
#  ('aún', 'aún'),
#  ('frente', 'frent'),
#  ('a', 'a'),
#  ('la', 'la'),
#  ('puerta', 'puerta'),
#  ('entré', 'entré'),
#  ('sin', 'sin'),
#  ('decir', 'decir'),
#  ('palabra', 'palabra'),
#  ('al', 'al'),
#  ('día', 'día'),
#  ('siguiente', 'siguient'),
#  ('huí', 'huí'),
#  ('de', 'de'),
#  ('aquel', 'aquel'),
#  ('pueblo', 'pueblo')]

# %%
nlp = spacy.load('es_core_news_sm')
# lematizamos con spacy, iterando sobre cada palabra del texto sin signos de puntuación
lematizacion_spacy = [(word.text,word.lemma_) for word in nlp(el_ramo_azul_prep)]
lematizacion_spacy
# Out:
# [('el', 'el'),
#  ('ramo', 'ramo'),
#  ('azul', 'azul'),
#  ('un', 'uno'),
#  ('cuento', 'contar'),
#  ('de', 'de'),
#  ('octavio', 'octavio'),
#  ('paz', 'paz'),
#  (' ', ' '),
#  ('desperté', 'despertar'),
#  ('cubierto', 'cubrir'),
#  ('de', 'de'),
#  ('sudor', 'sudor'),
#  ('del', 'del'),
#  ('piso', 'pisar'),
#  ('de', 'de'),
#  ('ladrillos', 'ladrillo'),
#  ('rojos', 'rojo'),
#  ('recién', 'recién'),
#  ('regados', 'regar'),
#  ('subía', 'subir'),
#  ('un', 'uno'),
#  ('vapor', 'vapor'),
#  ('caliente', 'calentar'),
#  ('una', 'uno'),
#  ('mariposa', 'mariposa'),
#  ('de', 'de'),
#  ('alas', 'ala'),
#  ('grisáceas', 'grisáceo'),
#  ('revoloteaba', 'revolotear'),
#  ('encandilada', 'encandilar'),
#  ('alrededor', 'alrededor'),
#  ('del', 'del'),
#  ('foco', 'foco'),
#  ('amarillento', 'amarillento'),
#  ('salté', 'saltar'),
#  ('de', 'de'),
#  ('la', 'lo'),
#  ('hamaca', 'hamaca'),
#  ('y', 'y'),
#  ('descalzo', 'descalzar'),
#  ('atravesé', 'atravesar'),
#  ('el', 'el'),
#  ('cuarto', 'cuartar'),
#  ('cuidando', 'cuidar'),
#  ('no', 'no'),
#  ('pisar', 'pisar'),
#  ('algún', 'alguno'),
#  ('alacrán', 'alacrán'),
#  ('salido', 'salir'),
#  ('de', 'de'),
#  ('su', 'su'),
#  ('escondrijo', 'escondrijo'),
#  ('a', 'a'),
#  ('tomar', 'tomar'),
#  ('el', 'el'),
#  ('fresco', 'fresco'),
#  ('me', 'me'),
#  ('acerqué', 'acercar'),
#  ('al', 'al'),
#  ('ventanillo', 'ventanillo'),
#  ('y', 'y'),
#  ('aspiré', 'aspirar'),
#  ('el', 'el'),
#  ('aire', 'aire'),
#  ('del', 'del'),
#  ('campo', 'campar'),
#  ('se', 'se'),
#  ('oía', 'oír'),
#  ('la', 'lo'),
#  ('respiración', 'respiración'),
#  ('de', 'de'),
#  ('la', 'lo'),
#  ('noche', 'noche'),
#  ('enorme', 'enorme'),
#  ('femenina', 'femenino'),
#  ('regresé', 'regresar'),
#  ('al', 'al'),
#  ('centro', 'centrar'),
#  ('de', 'de'),
#  ('la', 'lo'),
#  ('habitación', 'habitación'),
#  ('vacié', 'vaciar'),
#  ('el', 'el'),
#  ('agua', 'aguar'),
#  ('de', 'de'),
#  ('la', 'lo'),
#  ('jarra', 'jarra'),
#  ('en', 'en'),
#  ('la', 'lo'),
#  ('palangana', 'palangana'),
#  ('de', 'de'),
#  ('peltre', 'peltre'),
#  ('y', 'y'),
#  ('humedecí', 'humedecer'),
#  ('la', 'lo'),
#  ('toalla', 'toalla'),
#  ('me', 'me'),
#  ('froté', 'frotar'),
#  ('el', 'el'),
#  ('torso', 'torso'),
#  ('y', 'y'),
#  ('las', 'los'),
#  ('piernas', 'pierna'),
#  ('con', 'con'),
#  ('el', 'el'),
#  ('trapo', 'trapo'),
#  ('empapado', 'empapar'),
#  ('me', 'me'),
#  ('sequé', 'secar'),
#  ('un', 'uno'),
#  ('poco', 'poco'),
#  ('y', 'y'),
#  ('tras', 'tras'),
#  ('de', 'de'),
#  ('cerciorarme', 'cerciorarme'),
#  ('que', 'que'),
#  ('ningún', 'ninguno'),
#  ('bicho', 'bichar'),
#  ('estaba', 'estar'),
#  ('escondido', 'esconder'),
#  ('entre', 'entrar'),
#  ('los', 'lo'),
#  ('pliegues', 'pliegue'),
#  ('de', 'de'),
#  ('mi', 'mi'),
#  ('ropa', 'ropa'),
#  ('me', 'me'),
#  ('vestí', 'vestir'),
#  ('y', 'y'),
#  ('calcé', 'calzar'),
#  ('bajé', 'bajar'),
#  ('saltando', 'saltar'),
#  ('la', 'lo'),
#  ('escalera', 'escalera'),
#  ('pintada', 'pintar'),
#  ('de', 'de'),
#  ('verde', 'verde'),
#  ('en', 'en'),
#  ('la', 'lo'),
#  ('puerta', 'puerta'),
#  ('del', 'del'),
#  ('mesón', 'mesón'),
#  ('tropecé', 'tropezar'),
#  ('con', 'con'),
#  ('el', 'el'),
#  ('dueño', 'dueño'),
#  ('sujeto', 'sujetar'),
#  ('tuerto', 'tuerto'),
#  ('y', 'y'),
#  ('reticente', 'reticente'),
#  ('sentado', 'sentar'),
#  ('en', 'en'),
#  ('una', 'uno'),
#  ('sillita', 'sillita'),
#  ('de', 'de'),
#  ('tule', 'tule'),
#  ('fumaba', 'fumar'),
#  ('con', 'con'),
#  ('el', 'el'),
#  ('ojo', 'ojo'),
#  ('entrecerrado', 'entrecerrar'),
#  ('con', 'con'),
#  ('voz', 'voz'),
#  ('ronca', 'ronco'),
#  ('me', 'me'),
#  ('preguntó', 'preguntar'),
#  ('dónde', 'dónde'),
#  ('va', 'ir'),
#  ('señor', 'señor'),
#  (' ', ' '),
#  ('a', 'a'),
#  ('dar', 'dar'),
#  ('una', 'uno'),
#  ('vuelta', 'volver'),
#  ('hace', 'hacer'),
#  ('mucho', 'mucho'),
#  ('calor', 'calor'),
#  ('hum', 'hum'),
#  ('todo', 'todo'),
#  ('está', 'estar'),
#  ('ya', 'ya'),
#  ('cerrado', 'cerrar'),
#  ('y', 'y'),
#  ('no', 'no'),
#  ('hay', 'haber'),
#  ('alumbrado', 'alumbrar'),
#  ('aquí', 'aquí'),
#  ('más', 'más'),
#  ('le', 'le'),
#  ('valiera', 'valer'),
#  ('quedarse', 'quedarse'),
#  ('alcé', 'alzar'),
#  ('los', 'lo'),
#  ('hombros', 'hombro'),
#  ('musité', 'musitar'),
#  ('ahora', 'ahora'),
#  ('vuelvo', 'volver'),
#  ('y', 'y'),
#  ('me', 'me'),
#  ('metí', 'meter'),
#  ('en', 'en'),
#  ('lo', 'el'),
#  ('oscuro', 'oscuro'),
#  ('al', 'al'),
#  ('principio', 'principiar'),
#  ('no', 'no'),
#  ('veía', 'ver'),
#  ('nada', 'nadar'),
#  ('caminé', 'caminar'),
#  ('a', 'a'),
#  ('tientas', 'tienta'),
#  ('por', 'por'),
#  ('la', 'lo'),
#  ('calle', 'callar'),
#  ('empedrada', 'empedrar'),
#  ('encendí', 'encender'),
#  ('un', 'uno'),
#  ('cigarrillo', 'cigarrillo'),
#  ('de', 'de'),
#  ('pronto', 'pronto'),
#  ('salió', 'salir'),
#  ('la', 'lo'),
#  ('luna', 'luna'),
#  ('de', 'de'),
#  ('una', 'uno'),
#  ('nube', 'nube'),
#  ('negra', 'negro'),
#  ('iluminando', 'iluminar'),
#  ('un', 'uno'),
#  ('muro', 'murar'),
#  ('blanco', 'blanco'),
#  ('desmoronado', 'desmoronar'),
#  ('a', 'a'),
#  ('trechos', 'trecho'),
#  ('me', 'me'),
#  ('detuve', 'detener'),
#  ('ciego', 'cegar'),
#  ('ante', 'ante'),
#  ('tanta', 'tanto'),
#  ('blancura', 'blancura'),
#  ('sopló', 'soplar'),
#  ('un', 'uno'),
#  ('poco', 'poco'),
#  ('de', 'de'),
#  ('viento', 'viento'),
#  ('respiré', 'respirar'),
#  ('el', 'el'),
#  ('aire', 'aire'),
#  ('de', 'de'),
#  ('los', 'lo'),
#  ('tamarindos', 'tamarindo'),
#  ('vibraba', 'vibrar'),
#  ('la', 'lo'),
#  ('noche', 'noche'),
#  ('llena', 'lleno'),
#  ('de', 'de'),
#  ('hojas', 'hoja'),
#  ('e', 'e'),
#  ('insectos', 'insecto'),
#  ('los', 'lo'),
#  ('grillos', 'grillo'),
#  ('vivaqueaban', 'vivaquear'),
#  ('entre', 'entrar'),
#  ('las', 'los'),
#  ('hierbas', 'hierba'),
#  ('altas', 'alto'),
#  ('alcé', 'alzar'),
#  ('la', 'lo'),
#  ('cara', 'caro'),
#  ('arriba', 'arribar'),
#  ('también', 'también'),
#  ('habían', 'haber'),
#  ('establecido', 'establecer'),
#  ('campamento', 'campamento'),
#  ('las', 'los'),
#  ('estrellas', 'estrellar'),
#  ('pensé', 'pensar'),
#  ('que', 'que'),
#  ('el', 'el'),
#  ('universo', 'universo'),
#  ('era', 'ser'),
#  ('un', 'uno'),
#  ('vasto', 'vasto'),
#  ('sistema', 'sistema'),
#  ('de', 'de'),
#  ('señales', 'señalar'),
#  ('una', 'uno'),
#  ('conversación', 'conversación'),
#  ('entre', 'entrar'),
#  ('seres', 'ser'),
#  ('inmensos', 'inmenso'),
#  ('mis', 'mi'),
#  ('actos', 'acto'),
#  ('el', 'el'),
#  ('serrucho', 'serrucho'),
#  ('del', 'del'),
#  ('grillo', 'grillar'),
#  ('el', 'el'),
#  ('parpadeo', 'parpadear'),
#  ('de', 'de'),
#  ('la', 'lo'),
#  ('estrella', 'estrellar'),
#  ('no', 'no'),
#  ('eran', 'ser'),
#  ('sino', 'sino'),
#  ('pausas', 'pausar'),
#  ('y', 'y'),
#  ('sílabas', 'sílaba'),
#  ('frases', 'frase'),
#  ('dispersas', 'disperso'),
#  ('de', 'de'),
#  ('aquel', 'aquel'),
#  ('diálogo', 'diálogo'),
#  ('cuál', 'cuál'),
#  ('sería', 'ser'),
#  ('esa', 'ese'),
#  ('palabra', 'palabra'),
#  ('de', 'de'),
#  ('la', 'lo'),
#  ('cual', 'cual'),
#  ('yo', 'yo'),
#  ('era', 'ser'),
#  ('una', 'uno'),
#  ('sílaba', 'sílaba'),
#  ('quién', 'quién'),
#  ('dice', 'decir'),
#  ('esa', 'ese'),
#  ('palabra', 'palabra'),
#  ('y', 'y'),
#  ('a', 'a'),
#  ('quién', 'quién'),
#  ('se', 'se'),
#  ('la', 'lo'),
#  ('dice', 'decir'),
#  ('tiré', 'tirar'),
#  ('el', 'el'),
#  ('cigarrillo', 'cigarrillo'),
#  ('sobre', 'sobrar'),
#  ('la', 'lo'),
#  ('banqueta', 'banqueta'),
#  ('al', 'al'),
#  ('caer', 'caer'),
#  ('describió', 'describir'),
#  ('una', 'uno'),
#  ('curva', 'curvo'),
#  ('luminosa', 'luminoso'),
#  ('arrojando', 'arrojar'),
#  ('breves', 'breve'),
#  ('chispas', 'chispo'),
#  ('como', 'comer'),
#  ('un', 'uno'),
#  ('cometa', 'cometer'),
#  ('minúsculo', 'minúsculo'),
#  ('caminé', 'caminar'),
#  ('largo', 'largar'),
#  ('rato', 'rato'),
#  ('despacio', 'despacio'),
#  ('me', 'me'),
#  ('sentía', 'sentir'),
#  ('libre', 'librar'),
#  ('seguro', 'seguro'),
#  ('entre', 'entrar'),
#  ('los', 'lo'),
#  ('labios', 'labio'),
#  ('que', 'que'),
#  ('en', 'en'),
#  ('ese', 'ese'),
#  ('momento', 'momento'),
#  ('me', 'me'),
#  ('pronunciaban', 'pronunciar'),
#  ('con', 'con'),
#  ('tanta', 'tanto'),
#  ('felicidad', 'felicidad'),
#  ('la', 'lo'),
#  ('noche', 'noche'),
#  ('era', 'ser'),
#  ('un', 'uno'),
#  ('jardín', 'jardín'),
#  ('de', 'de'),
#  ('ojos', 'ojo'),
#  ('al', 'al'),
#  ('cruzar', 'cruzar'),
#  ('la', 'lo'),
#  ('calle', 'callar'),
#  ('sentí', 'sentir'),
#  ('que', 'que'),
#  ('alguien', 'alguien'),
#  ('se', 'se'),
#  ('desprendía', 'desprender'),
#  ('de', 'de'),
#  ('una', 'uno'),
#  ('puerta', 'puerta'),
#  ('me', 'me'),
#  ('volví', 'volver'),
#  ('pero', 'pero'),
#  ('no', 'no'),
#  ('acerté', 'acertar'),
#  ('a', 'a'),
#  ('distinguir', 'distinguir'),
#  ('nada', 'nadar'),
#  ('apreté', 'apretar'),
#  ('el', 'el'),
#  ('paso', 'pasar'),
#  ('unos', 'uno'),
#  ('instantes', 'instante'),
#  ('percibí', 'percibir'),
#  ('unos', 'uno'),
#  ('huaraches', 'huaraches'),
#  ('sobre', 'sobrar'),
#  ('las', 'los'),
#  ('piedras', 'piedra'),
#  ('calientes', 'caliente'),
#  ('no', 'no'),
#  ('quise', 'querer'),
#  ('volverme', 'volverme'),
#  ('aunque', 'aunque'),
#  ('sentía', 'sentir'),
#  ('que', 'que'),
#  ('la', 'lo'),
#  ('sombra', 'sombrar'),
#  ('se', 'se'),
#  ('acercaba', 'acercar'),
#  ('cada', 'cada'),
#  ('vez', 'vez'),
#  ('más', 'más'),
#  ('intenté', 'intentar'),
#  ('correr', 'correr'),
#  ('no', 'no'),
#  ('pude', 'poder'),
#  ('me', 'me'),
#  ('detuve', 'detener'),
#  ('en', 'en'),
#  ('seco', 'secar'),
#  ('bruscamente', 'bruscamente'),
#  ('antes', 'antes'),
#  ('de', 'de'),
#  ('que', 'que'),
#  ('pudiese', 'poder'),
#  ('defenderme', 'defenderme'),
#  ('sentí', 'sentir'),
#  ('la', 'lo'),
#  ('punta', 'punta'),
#  ('de', 'de'),
#  ('un', 'uno'),
#  ('cuchillo', 'cuchillo'),
#  ('en', 'en'),
#  ('mi', 'mi'),
#  ('espalda', 'espalda'),
#  ('y', 'y'),
#  ('una', 'uno'),
#  ('voz', 'voz'),
#  ('dulce', 'dulce'),
#  ('no', 'no'),
#  ('se', 'se'),
#  ('mueva', 'mover'),
#  (' ', ' '),
#  ('señor', 'señor'),
#  ('o', 'o'),
#  ('se', 'se'),
#  ('lo', 'el'),
#  ('entierro', 'enterrar'),
#  ('sin', 'sin'),
#  ('volver', 'volver'),
#  ('la', 'lo'),
#  ('cara', 'caro'),
#  ('pregunté', 'preguntar'),
#  ('qué', 'qué'),
#  ('quieres', 'querer'),
#  ('sus', 'su'),
#  ('ojos', 'ojo'),
#  ('señor', 'señor'),
#  ('contestó', 'contestar'),
#  ('la', 'lo'),
#  ('voz', 'voz'),
#  ('suave', 'suave'),
#  ('casi', 'casi'),
#  ('apenada', 'apenar'),
#  ('mis', 'mi'),
#  ('ojos', 'ojo'),
#  ('para', 'parir'),
#  ('qué', 'qué'),
#  ('te', 'te'),
#  ('servirán', 'servir'),
#  ('mis', 'mi'),
#  ('ojos', 'ojo'),
#  ('mira', 'mirar'),
#  ('aquí', 'aquí'),
#  ('tengo', 'tener'),
#  ('un', 'uno'),
#  ('poco', 'poco'),
#  ('de', 'de'),
#  ('dinero', 'dinero'),
#  ('no', 'no'),
#  ('es', 'ser'),
#  ('mucho', 'mucho'),
#  ('pero', 'pero'),
#  ('es', 'ser'),
#  ('algo', 'algo'),
#  ('te', 'te'),
#  ('daré', 'dar'),
#  ('todo', 'todo'),
#  ('lo', 'el'),
#  ('que', 'que'),
#  ('tengo', 'tener'),
#  ('si', 'si'),
#  ('me', 'me'),
#  ('dejas', 'dejar'),
#  ('no', 'no'),
#  ('vayas', 'vaya'),
#  ('a', 'a'),
#  ('matarme', 'matarme'),
#  ('no', 'no'),
#  ('tenga', 'tener'),
#  ('miedo', 'miedo'),
#  ('señor', 'señor'),
#  ('no', 'no'),
#  ('lo', 'el'),
#  ('mataré', 'matar'),
#  ('nada', 'nadar'),
#  ('más', 'más'),
#  ('voy', 'ir'),
#  ('a', 'a'),
#  ('sacarle', 'sacarle'),
#  ('los', 'lo'),
#  ('ojos', 'ojo'),
#  ('pero', 'pero'),
#  ('para', 'parir'),
#  ('qué', 'qué'),
#  ('quieres', 'querer'),
#  ('mis', 'mi'),
#  ('ojos', 'ojo'),
#  ('es', 'ser'),
#  ('un', 'uno'),
#  ('capricho', 'capricho'),
#  ('de', 'de'),
#  ('mi', 'mi'),
#  ('novia', 'novio'),
#  ('quiere', 'querer'),
#  ('un', 'uno'),
#  ('ramito', 'ramito'),
#  ('de', 'de'),
#  ('ojos', 'ojo'),
#  ('azules', 'azular'),
#  ('y', 'y'),
#  ('por', 'por'),
#  ('aquí', 'aquí'),
#  ('hay', 'haber'),
#  ('pocos', 'poco'),
#  ('que', 'que'),
#  ('los', 'lo'),
#  ('tengan', 'tener'),
#  ('mis', 'mi'),
#  ('ojos', 'ojo'),
#  ('no', 'no'),
#  ('te', 'te'),
#  ('sirven', 'servir'),
#  ('no', 'no'),
#  ('son', 'ser'),
#  ('azules', 'azular'),
#  ('sino', 'sino'),
#  ('amarillos', 'amarillo'),
#  ('ay', 'ay'),
#  ('señor', 'señor'),
#  ('no', 'no'),
#  ('quiera', 'querer'),
#  ('engañarme', 'engañarme'),
#  ('bien', 'bien'),
#  ('sé', 'ser'),
#  ('que', 'que'),
#  ('los', 'lo'),
#  ('tiene', 'tener'),
#  ('azules', 'azular'),
#  ('no', 'no'),
#  ('se', 'se'),
#  ('le', 'le'),
#  ('sacan', 'sacar'),
#  ('a', 'a'),
#  ('un', 'uno'),
#  ('cristiano', 'cristianar'),
#  ('los', 'lo'),
#  ('ojos', 'ojo'),
#  ('así', 'asir'),
#  ('te', 'te'),
#  ('daré', 'dar'),
#  ('otra', 'otro'),
#  ('cosa', 'coser'),
#  ('no', 'no'),
#  ('se', 'se'),
#  ('haga', 'hacer'),
#  ('el', 'el'),
#  ('remilgoso', 'remilgoso'),
#  ('me', 'me'),
#  ('dijo', 'decir'),
#  ('con', 'con'),
#  ('dureza', 'dureza'),
#  ('dé', 'dar'),
#  ('la', 'lo'),
#  ('vuelta', 'volver'),
#  ('me', 'me'),
#  ('volví', 'volver'),
#  ('era', 'ser'),
#  ('pequeño', 'pequeño'),
#  ('y', 'y'),
#  ('frágil', 'frágil'),
#  ('el', 'el'),
#  ('sombrero', 'sombrero'),
#  ('de', 'de'),
#  ('palma', 'palmar'),
#  ('le', 'le'),
#  ('cubría', 'cubrir'),
#  ('medio', 'mediar'),
#  ('rostro', 'rostro'),
#  ('sostenía', 'sostener'),
#  ('con', 'con'),
#  ('el', 'el'),
#  ('brazo', 'brazo'),
#  ('derecho', 'derecho'),
#  ('un', 'uno'),
#  ('machete', 'machete'),
#  ('de', 'de'),
#  ('campo', 'campar'),
#  ('que', 'que'),
#  ('brillaba', 'brillar'),
#  ('con', 'con'),
#  ('la', 'lo'),
#  ('luz', 'luz'),
#  ('de', 'de'),
#  ('la', 'lo'),
#  ('luna', 'luna'),
#  ('alúmbrese', 'alúmbrese'),
#  ('la', 'lo'),
#  ('cara', 'caro'),
#  ('encendí', 'encender'),
#  ('y', 'y'),
#  ('me', 'me'),
#  ('acerqué', 'acercar'),
#  ('la', 'lo'),
#  ('llama', 'llamar'),
#  ('al', 'al'),
#  ('rostro', 'rostro'),
#  ('el', 'el'),
#  ('resplandor', 'resplandor'),
#  ('me', 'me'),
#  ('hizo', 'hacer'),
#  ('entrecerrar', 'entrecerrar'),
#  ('los', 'lo'),
#  ('ojos', 'ojo'),
#  ('el', 'el'),
#  ('apartó', 'apartar'),
#  ('mis', 'mi'),
#  ('párpados', 'párpado'),
#  ('con', 'con'),
#  ('mano', 'manir'),
#  ('firme', 'firmar'),
#  ('no', 'no'),
#  ('podía', 'poder'),
#  ('ver', 'ver'),
#  ('bien', 'bien'),
#  ('se', 'se'),
#  ('alzó', 'alzar'),
#  ('sobre', 'sobrar'),
#  ('las', 'los'),
#  ('puntas', 'punta'),
#  ('de', 'de'),
#  ('los', 'lo'),
#  ('pies', 'pie'),
#  ('y', 'y'),
#  ('me', 'me'),
#  ('contempló', 'contemplar'),
#  ('intensamente', 'intensamente'),
#  ('la', 'lo'),
#  ('llama', 'llamar'),
#  ('me', 'me'),
#  ('quemaba', 'quemar'),
#  ('los', 'lo'),
#  ('dedos', 'dedo'),
#  ('la', 'lo'),
#  ('arrojé', 'arrojar'),
#  ('permaneció', 'permanecer'),
#  ('un', 'uno'),
#  ('instante', 'instante'),
#  ('silencioso', 'silencioso'),
#  ('ya', 'ya'),
#  ('te', 'te'),
#  ('convenciste', 'convencer'),
#  ('no', 'no'),
#  ('los', 'lo'),
#  ('tengo', 'tener'),
#  ('azules', 'azular'),
#  ('ah', 'ah'),
#  ('qué', 'qué'),
#  ('mañoso', 'mañoso'),
#  ('es', 'ser'),
#  ('usted', 'tú'),
#  ('respondió', 'responder'),
#  ('a', 'a'),
#  ('ver', 'ver'),
#  ('encienda', 'encender'),
#  ('otra', 'otro'),
#  ('vez', 'vez'),
#  ('froté', 'frotar'),
#  ('otro', 'otro'),
#  ('fósforo', 'fósforo'),
#  ('y', 'y'),
#  ('lo', 'el'),
#  ('acerqué', 'acercar'),
#  ('a', 'a'),
#  ('mis', 'mi'),
#  ('ojos', 'ojo'),
#  ('tirándome', 'tirándome'),
#  ('de', 'de'),
#  ('la', 'lo'),
#  ('manga', 'mangar'),
#  ('me', 'me'),
#  ('ordenó', 'ordenar'),
#  ('arrodíllese', 'arrodíllese'),
#  ('mi', 'mi'),
#  ('hinqué', 'hincar'),
#  ('con', 'con'),
#  ('una', 'uno'),
#  ('mano', 'manir'),
#  ('me', 'me'),
#  ('cogió', 'coger'),
#  ('por', 'por'),
#  ('los', 'lo'),
#  ('cabellos', 'cabello'),
#  ('echándome', 'echándome'),
#  ('la', 'lo'),
#  ('cabeza', 'cabeza'),
#  ('hacia', 'hacia'),
#  ('atrás', 'atrás'),
#  ('se', 'se'),
#  ('inclinó', 'inclinar'),
#  ('sobre', 'sobrar'),
#  ('mí', 'mí'),
#  ('curioso', 'curioso'),
#  ('y', 'y'),
#  ('tenso', 'tensar'),
#  ('mientras', 'mientras'),
#  ('el', 'el'),
#  ('machete', 'machete'),
#  ('descendía', 'descender'),
#  ('lentamente', 'lentamente'),
#  ('hasta', 'hasta'),
#  ('rozar', 'rozar'),
#  ('mis', 'mi'),
#  ('párpados', 'párpado'),
#  ('cerré', 'cerrar'),
#  ('los', 'lo'),
#  ('ojos', 'ojo'),
#  ('ábralos', 'ábralos'),
#  ('bien', 'bien'),
#  ('ordenó', 'ordenar'),
#  ('abrí', 'abrir'),
#  ('los', 'lo'),
#  ('ojos', 'ojo'),
#  ('la', 'lo'),
#  ('llamita', 'llamita'),
#  ('me', 'me'),
#  ('quemaba', 'quemar'),
#  ('las', 'los'),
#  ('pestañas', 'pestaña'),
#  ('me', 'me'),
#  ('soltó', 'soltar'),
#  ('de', 'de'),
#  ('improviso', 'improvisar'),
#  ('pues', 'pues'),
#  ('no', 'no'),
#  ('son', 'ser'),
#  ('azules', 'azular'),
#  ('señor', 'señor'),
#  ('dispense', 'dispensar'),
#  ('y', 'y'),
#  ('despareció', 'despareció'),
#  ('me', 'me'),
#  ('acodé', 'acodar'),
#  ('junto', 'juntar'),
#  ('al', 'al'),
#  ('muro', 'murar'),
#  ('con', 'con'),
#  ('la', 'lo'),
#  ('cabeza', 'cabeza'),
#  ('entre', 'entrar'),
#  ('las', 'los'),
#  ('manos', 'mano'),
#  ('luego', 'luego'),
#  ('me', 'me'),
#  ('incorporé', 'incorporar'),
#  ('a', 'a'),
#  ('tropezones', 'tropezón'),
#  ('cayendo', 'caer'),
#  ('y', 'y'),
#  ('levantándome', 'levantándome'),
#  ('corrí', 'correr'),
#  ('durante', 'durante'),
#  ('una', 'uno'),
#  ('hora', 'hora'),
#  ('por', 'por'),
#  ('el', 'el'),
#  ('pueblo', 'poblar'),
#  ('desierto', 'desierto'),
#  ('cuando', 'cuando'),
#  ('llegué', 'llegar'),
#  ('a', 'a'),
#  ('la', 'lo'),
#  ('plaza', 'plaza'),
#  ('vi', 'ver'),
#  ('al', 'al'),
#  ('dueño', 'dueño'),
#  ('del', 'del'),
#  ('mesón', 'mesón'),
#  ('sentado', 'sentar'),
#  ('aún', 'aun'),
#  ('frente', 'frente'),
#  ('a', 'a'),
#  ('la', 'lo'),
#  ('puerta', 'puerta'),
#  ('entré', 'entrar'),
#  ('sin', 'sin'),
#  ('decir', 'decir'),
#  ('palabra', 'palabra'),
#  ('al', 'al'),
#  ('día', 'día'),
#  ('siguiente', 'siguiente'),
#  ('huí', 'huir'),
#  ('de', 'de'),
#  ('aquel', 'aquel'),
#  ('pueblo', 'poblar')]

# %% [markdown]
# NOTA: Spacy no tiene para stemming

# %% [markdown]
# 3. ¿Cuántas palabras diferentes hay?

# %%
print("Hay {} diferentes palabras".format(len(set(tokens))))
# Out:
# Hay 435 diferentes palabras

# %% [markdown]
# 4. Después de lematizar las palabras, ¿cuántas palabras diferentes hay?

# %%
# para obtener los lemas, extraemos el segundo elemento de cada tupla en la lista
print("Después de lematizar las palabras con nltk, hay {} diferentes palabras".format(len(set([l[1] for l in lemas]))))
# Out:
# Después de lematizar las palabras con nltk, hay 431 diferentes palabras

# %%
# para obtener los lemas de spacy, extraemos el segundo elemento de cada tupla en la lista
# Le resto un 1 porque hay una tupla así: (' ',' ')
print("Después de lematizar las palabras con spacy, hay {} diferentes palabras".format(len(set([l[1] for l in lematizacion_spacy]))-1))
# Out:
# Después de lematizar las palabras con spacy, hay 376 diferentes palabras

# %% [markdown]
# 5. ¿Cuál es la diversidad léxica del texto dado? (relación de palabras únicas con respecto al número total de palabras)

# %%
# dividimos palabras distintas entre el total de palabras del texto
print("La diversidad léxica del texto dado es de: {}".format(len(set(tokens)) / len(tokens)))
# Out:
# La diversidad léxica del texto dado es de: 0.5266343825665859

# %% [markdown]
# 6. ¿Cuáles son las 20 palabras léxicas más frecuentes en el texto? ¿Cuál es su frecuencia?

# %%
# obtenemos en una lista las palabras que NO son stop words del texto
tokens_no_stop_words_esp = [p for p in tokens if p not in stopwords.words('spanish')]
# contamos la frecuencia de todas las palabras usando la lista anterior
frecuencia_palabras = nltk.FreqDist(tokens_no_stop_words_esp)
# el método "most_common(n)" brinda una lista de las n tuplas (la primera entrada 
# de cada tupla es la palabra y la segunda entrada es su frecuencia) que tienen en su segunda
# entrada la frecuencia (y las da en orden descendiente)
print("Las 20 palabras léxicas más frecuentes en el texto, con su respectiva frecuencia, son:\n", frecuencia_palabras.most_common(20))
# Out:
# Las 20 palabras léxicas más frecuentes en el texto, con su respectiva frecuencia, son:
#  [('ojos', 13), ('señor', 6), ('azules', 5), ('acerqué', 3), ('noche', 3), ('puerta', 3), ('voz', 3), ('aquí', 3), ('cara', 3), ('palabra', 3), ('bien', 3), ('aire', 2), ('campo', 2), ('froté', 2), ('mesón', 2), ('dueño', 2), ('sentado', 2), ('vuelta', 2), ('alcé', 2), ('caminé', 2)]

# %% [markdown]
# 7. ¿Cuál es el número promedio de palabras por oración?

# %%
# extraemos todas las oraciones
sent_tokenize_el_ramo_azul = nltk.tokenize.sent_tokenize(el_ramo_azul)

# la primera oración contiene al título del texto, por lo que no lo voy a considerar en esta parte
sent_tokenize_el_ramo_azul[0] = sent_tokenize_el_ramo_azul[0][39:-1]
print("Hay {} oraciones.".format(len(sent_tokenize_el_ramo_azul)))
# Out:
# Hay 105 oraciones.

# %%
# creamos una lista vacía en la que colocaremos la cantidad de palabras que tiene cada oración del texto
num_palabras_por_oración = []
for i in range(len(sent_tokenize_el_ramo_azul)):
    palabras = sent_tokenize_el_ramo_azul[i].split()
    num_palabras_por_oración.append(len(palabras))
#calculamos el promedio   
promedio = sum(num_palabras_por_oración)/len(sent_tokenize_el_ramo_azul)
print("El número promedio de palabras por oración es de: ", promedio)
# Out:
# El número promedio de palabras por oración es de:  7.8

# %% [markdown]
# 8. ¿Cuál  es la frecuencia de sustantivos, adjetivos y verbos en el texto?.

# %%
# parte del etiquetador (part of speech) para etiquetar la lista de los tokens.
el_ramo_azul_tagged = nltk.pos_tag(tokens)
# contamos la frecuencia de cada pos (part of speech)
tag_fd = nltk.FreqDist(tag for(word, tag) in el_ramo_azul_tagged)
# calculamos la frecuencia de cada POS
tag_fd.most_common()
# Out:
# [('NN', 376),
#  ('FW', 148),
#  ('JJ', 111),
#  ('IN', 40),
#  ('DT', 34),
#  ('VBP', 28),
#  ('VBZ', 25),
#  ('PRP', 24),
#  ('NNS', 17),
#  ('RB', 8),
#  ('VB', 7),
#  ('VBD', 4),
#  ('VBN', 1),
#  ('CC', 1),
#  ('PDT', 1),
#  ('NNP', 1)]

# %%
# De la lista de tuplas que acabamos de obtener, nos quedamos con los que empiecen con NN,
# los cuales indican que son sustantivos

es_sustantivo = lambda pos: pos[:2] == 'NN'
sustantivos = [palabra for (palabra, pos) in el_ramo_azul_tagged if es_sustantivo(pos)] 
print("La frecuencia de sustantivos, usando nltk, es de {}".format(len(sustantivos)))
# Out:
# La frecuencia de sustantivos, usando nltk, es de 394

# %%
# De la lista de tuplas que acabamos de obtener, nos quedamos con los que empiecen con JJ,
# los cuales indican que son adjetivos

es_adjetivo = lambda pos: pos[:2] == 'JJ'
adjetivos = [palabra for (palabra, pos) in el_ramo_azul_tagged if es_adjetivo(pos)] 
print("La frecuencia de adjetivos, usando nltk, es de {}".format(len(adjetivos)))
# Out:
# La frecuencia de adjetivos, usando nltk, es de 111

# %%
# De la lista de tuplas que acabamos de obtener, nos quedamos con los que empiecen con VB,
# los cuales indican que son verbos
es_verbo = lambda pos: pos[:2] == 'VB'
verbos = [palabra for (palabra, pos) in el_ramo_azul_tagged if es_verbo(pos)] 
print("La frecuencia de verbos, usando nltk, es de {}".format(len(verbos)))
# Out:
# La frecuencia de verbos, usando nltk, es de 65

# %%
# usando spacy

# contamos la frecuencia de cada pos del archivo sin signos de puntuacion
# counter arroja algo como un diccionario, donde la llave es el pos y el
# valor de la llave es su frecuencia en el texto
c = Counter(([token.pos_ for token in nlp(el_ramo_azul_prep)]))
c
# Out:
# Counter({'DET': 135,
#          'NOUN': 172,
#          'ADJ': 72,
#          'ADP': 107,
#          'SPACE': 3,
#          'VERB': 118,
#          'ADV': 53,
#          'AUX': 38,
#          'PROPN': 8,
#          'CCONJ': 27,
#          'PRON': 71,
#          'INTJ': 8,
#          'SCONJ': 16,
#          'NUM': 1})

# %%
print("La frecuencia de sustantivos, usando spacy, es de {}".format(c['NOUN']))
# Out:
# La frecuencia de sustantivos, usando spacy, es de 172

# %%
print("La frecuencia de adjetivos, usando spacy, es de {}".format(c['ADJ']))
# Out:
# La frecuencia de adjetivos, usando spacy, es de 72

# %%
print("La frecuencia de verbos, usando spacy, es de {}".format(c['VERB']))
# Out:
# La frecuencia de verbos, usando spacy, es de 118

# %% [markdown]
# Vemos que cambia la frecuencia de esos tres POS si usamos nltk o spacy
